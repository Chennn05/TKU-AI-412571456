# %% [markdown]
# <a href="https://colab.research.google.com/github/Chennn05/TKU-AI-412571456/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hi")
# Out:
# Hi

# %%
a=1

# %%
b=2

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
print(a)
# Out:
# 1

# %%
c=d=e=3

# %%
c,d,e
# Out:
# (3, 3, 3)

# %%
print(c)
# Out:
# 3

# %%
print(d)
# Out:
# 3

# %%
print(e)
# Out:
# 3

# %%
A=2

# %%
a
# Out:
# 1

# %%
A
# Out:
# 2

# %%
變數=1

# %%
變數
# Out:
# 1

# %%
print("你好")
# Out:
# 你好

# %%
f=1
#g=2
h=3

# %%
f
# Out:
# 1

# %%
g
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-a5938ace3f42> in <cell line: 1>()
# ----> 1 g
#
# NameError: name 'g' is not defined

# %%
h
# Out:
# 3

# %%
i=4
j=5
#k=6

# %%
i
# Out:
# 4

# %%
j
# Out:
# 5

# %%
k
# Out:
# 6
